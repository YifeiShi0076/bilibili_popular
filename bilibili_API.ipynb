# %%
import requests
import json
import os

# %%
def load_cookies(file_path):
    """
    从文件中加载 Cookie 并返回字符串
    """
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            cookies = file.read().strip()
            return cookies
    except FileNotFoundError:
        print(f"Cookie 文件未找到: {file_path}")
        return None
    except Exception as e:
        print(f"读取 Cookie 文件时出错: {e}")
        return None

# %%
# 定义cookie内容文件路径
cookie_file_path = os.path.join(os.getcwd(), "cookies.txt")
# 加载 Cookie
cookies = load_cookies(cookie_file_path)
print(cookies)
# Out:
# buvid3=EAA865F3-78A7-DDA1-AFB2-45B889942D4E63454infoc; b_nut=1741444563; _uuid=1F7F6C39-DF101-9396-B1077-1C4E527A101AC62871infoc; enable_web_push=DISABLE; enable_feed_channel=ENABLE; DedeUserID=497403294; DedeUserID__ckMd5=655ec9faf463886d; LIVE_BUVID=AUTO8817414446344917; PVID=2; header_theme_version=CLOSE; rpdid=|(JYYJJk~m~)0J'u~RuR)mu)~; buvid4=A3C08EE8-76C8-6C81-026D-83F2EE1FB05768985-024082614-2LSV8bAhVjTt1j%2F%2B2f5Wpg%3D%3D; CURRENT_QUALITY=112; fingerprint=8f77e620acf296c9024f5c5457a27b5d; buvid_fp_plain=undefined; buvid_fp=8f77e620acf296c9024f5c5457a27b5d; home_feed_column=5; browser_resolution=1552-719; hit-dyn-v2=1; bili_ticket=eyJhbGciOiJIUzI1NiIsImtpZCI6InMwMyIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NDgwOTEwNzgsImlhdCI6MTc0NzgzMTgxOCwicGx0IjotMX0.fXi0APaG8eYNVbF3UFFy2i7zGyM9p1oajX8fAsoccTI; bili_ticket_expires=1748091018; SESSDATA=8a325c38%2C1763473340%2C87e61%2A52CjDBUIE_VoQ2ZB3uERVrnE0N7W-35k-QKkVYcgmnU2U4tWP0P4n4cKaDtEU7T-Q9VYkSVjRIWWktM0swajQzdk5rWUd0d0VQU2NzSXlzTm5SU2Z6VHpOUExlQzh5NENQUEFNMGt4ajJDRkZYOGRIUzJHeUN2VURmdktKOW9HQS1HNHNrcVJ4VDRnIIEC; bili_jct=fe665230df1b6c6775d3eed297518d0d; bp_t_offset_497403294=1069807492222943232; CURRENT_FNVAL=4048; b_lsid=1086C102E1_19700D2B8F6

# %%
url = "https://api.bilibili.com/x/web-interface/popular/series/one?number=321"

headers = {
    "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-encoding":"gzip, deflate, br, zstd",
    "accept-language":"zh-CN,zh;q=0.9,en;q=0.8",
    "cache-control":"max-age=0",
    "cookie":cookies,
    "priority":"u=0, i",
    "sec-ch-ua":'''"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"''',
    "sec-ch-ua-mobile":"?0",
    "sec-ch-ua-platform":'''"Windows"''',
    "sec-fetch-dest":"document",
    "sec-fetch-mode":"navigate",
    "sec-fetch-site":"none",
    "sec-fetch-user":"?1",
    "upgrade-insecure-requests":"1",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"
}

# 发起请求
response = requests.get(url, headers=headers)

json_data = response.text
data_dict = json.loads(json_data)

data_dict
# Out:
# {'code': 0,
#  'message': '0',
#  'ttl': 1,
#  'data': {'config': {'id': 326,
#    'type': 'weekly_selected',
#    'number': 321,
#    'subject': '揭秘人生进度条',
#    'stime': 1746720000,
#    'etime': 1747324799,
#    'status': 2,
#    'name': '2025第321期 05.09 - 05.15',
#    'label': '第321期(0516更新)',
#    'hint': '',
#    'color': 0,
#    'cover': '',
#    'share_title': '揭秘人生进度条｜每周必看第320期',
#    'share_subtitle': '一个定律就能预言人生？毕导带你了解本福特定律',
#    'media_id': 3558439788},
#   'reminder': '每周五晚18:00更新',
#   'list': [{'aid': 114478410699738,
#     'videos': 1,
#     'tid': 201,
#     'tname': '科学科普',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/c8f962efc6e16e623cb6e72684ed015328f7b248.jpg',
#     'title': '【毕导】这个定律，预言了你的人生进度条',
#     'pubdate': 1746846000,
#     'ctime': 1746802310,
#     'desc': '好奇怪啊！一秒、一天、一年的时长从来没有变过。为什么我们会觉得时间越过越快呢？\n这个问题可不是心理学的错觉，或许看完这个视频，你就会明白自己为什么总是怀念童年。\n\n你还可以看看: \n在这个简单的问题上，你学的教材可能一直是错的  BV1ZJ9CY4EzR \n击溃你的常识!无穷之后的世界是什么样?  BV1gcfWYqEsf \n世界上最强的酸，比纯硫酸强一亿亿倍?  BV11yrkYME4G \n你有一种连你自己都没意识到的超能力  BV12hz2Y1E3B',
#     'state': 0,
#     'duration': 739,
#     'mission_id': 4031781,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 254463269,
#      'name': '毕导',
#      'face': 'https://i2.hdslb.com/bfs/face/a59d6b2dff6faa47bc07877b76f3194c598f5649.jpg'},
#     'stat': {'aid': 114478410699738,
#      'view': 5816127,
#      'danmaku': 22026,
#      'reply': 12017,
#      'favorite': 226344,
#      'coin': 284269,
#      'share': 61497,
#      'now_rank': 0,
#      'his_rank': 1,
#      'like': 533467,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 5816127,
#      'fav_g': 47960,
#      'like_g': 0},
#     'dynamic': '诡异的1，才是自然和你的本质',
#     'cid': 29894248891,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1VrVSz1Eme',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250510sa7hx9zm7i3o3l2fdujfguke8_firsti.jpg',
#     'pub_location': '浙江',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/3176041161ed8afe1fc4bb642deb59fcd79f7fa6.jpg',
#     'tidv2': 2094,
#     'tnamev2': '科学科普',
#     'pid_v2': 1010,
#     'pid_name_v2': '知识',
#     'bvid': 'BV1VrVSz1Eme',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '为什么时间过得这么快？毕导告诉你人生的秘密'},
#    {'aid': 114484081335261,
#     'videos': 1,
#     'tid': 172,
#     'tname': '手机游戏',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/7696018636ea5f7448bf6da120f8c07f1c0c4aba.jpg',
#     'title': '选 择 你 的 干 员 ！',
#     'pubdate': 1746928800,
#     'ctime': 1746888704,
#     'desc': '选择你的干员！下期将前往原神x三角洲烽火地带！\nBYD这鬼动作真难K,夜兰拉弓的动作K麻了。\n借物表：\n原神-元素战争人物、武器模型：Notables\nblender枪械火控系统几何节点：Kewow\n动作K帧参考：三角洲行动\n三角洲模型以及特勤处场景购买自小黄鱼（需要的来我粉丝群免费拿）\n其余枪械武器：COD19、20\n崩铁易拉罐：静雨闻风\n冲浪时光 ：RK贝今天也很快乐\n牢大专武（鎏金监督）：芙生一梦',
#     'state': 0,
#     'duration': 108,
#     'mission_id': 4036628,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 88070980,
#      'name': 'Ty丶童心未泯',
#      'face': 'https://i1.hdslb.com/bfs/face/926218534cf83782cffb1b549972014bc1737e79.jpg'},
#     'stat': {'aid': 114484081335261,
#      'view': 6174432,
#      'danmaku': 5412,
#      'reply': 12642,
#      'favorite': 333034,
#      'coin': 126838,
#      'share': 123695,
#      'now_rank': 0,
#      'his_rank': 2,
#      'like': 540912,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 6174432,
#      'fav_g': 102674,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29896016153,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 540811,
#     'short_link_v2': 'https://b23.tv/BV1NhVZzsEdd',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250511a23acztackzk6ls1fhpcim0su_firsti.jpg',
#     'pub_location': '黑龙江',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/1d0629579449cfd79c527e28fbcc89012e507126.jpg',
#     'tidv2': 2037,
#     'tnamev2': '同人动画',
#     'pid_v2': 1005,
#     'pid_name_v2': '二次元',
#     'bvid': 'BV1NhVZzsEdd',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '“蒙德城门口三可莉堵桥来”'},
#    {'aid': 114486983786577,
#     'videos': 1,
#     'tid': 21,
#     'tname': '日常',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/27e22006cde5d6444bfc0cd6a17eb567c72f3082.jpg',
#     'title': '挤爆了！！6个up主假期旺季去最热门景点旅游...【青春旅行团08】',
#     'pubdate': 1746936293,
#     'ctime': 1746933857,
#     'desc': '全！新！系！列！！《青春旅行团》第二季,第二期！！\n随机一个人策划一期旅游，结果......\n喜欢的话请多多一键三连吧！',
#     'state': 0,
#     'duration': 2982,
#     'mission_id': 4034168,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 1,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 147166910,
#      'name': '雨哥到处跑',
#      'face': 'https://i2.hdslb.com/bfs/face/c54b148c789fcf43da95eb81331af6de47511553.jpg'},
#     'stat': {'aid': 114486983786577,
#      'view': 3918015,
#      'danmaku': 81985,
#      'reply': 6801,
#      'favorite': 104658,
#      'coin': 239411,
#      'share': 13476,
#      'now_rank': 0,
#      'his_rank': 3,
#      'like': 288528,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 3918015,
#      'fav_g': 28184,
#      'like_g': 0},
#     'dynamic': '全！新！系！列！来！拉！！\n《青春旅行团》第二季！第二期！\n这一期我带大家去了最最最热门的景点旅游，挤死了！但是好好玩！！！',
#     'cid': 29903949510,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1WpETzxEiZ',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250511sa1o1jn2iebu63w1q3vybypmv_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/f838fce33310dcb15e67a59f2b81bfef03caf936.jpg',
#     'tidv2': 2156,
#     'tnamev2': 'UP主小综艺',
#     'pid_v2': 1021,
#     'pid_name_v2': '小剧场',
#     'bvid': 'BV1WpETzxEiZ',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '青旅请一直拍下去吧！'},
#    {'aid': 114478595182435,
#     'videos': 1,
#     'tid': 182,
#     'tname': '影视杂谈',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/9834a96c8d380e52ea9999acccd9e219a024e1ff.jpg',
#     'title': '这就是顶级杀手的食量',
#     'pubdate': 1746804981,
#     'ctime': 1746804981,
#     'desc': '大家好，这里是《心中之城》。\n\xa0\n《豺狼的日子》第五期解说到此结束。\n\xa0\n比计划提前做好了，感受到大家的期待，心中充满感谢和惶恐，不敢休太久，吭哧吭哧赶了出来。\n\xa0\n第六期，将会是《豺狼的日子》解说最终期。我会尽快做出来。而如果有朋友愿意去欣赏原片，那当然很好。\n\xa0\n在这期，我们知道了豺狼的过去。他是一个目睹了屠杀，然后屠杀了所有罪人的人。可我猜测，那场屠杀的回忆中，使豺狼永不能寐的，是他自己开的那一枪。他开枪消灭了远方山坡上，一个持枪瞄准他队友的威胁。结果，那人不是狙击手，那人拿的只是一支突击步枪。在那',
#     'state': 0,
#     'duration': 1708,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 37701227,
#      'name': '心中之城_',
#      'face': 'https://i2.hdslb.com/bfs/face/60bd3ada68be6e34fc4be7bd03f3ebb124ba5533.jpg'},
#     'stat': {'aid': 114478595182435,
#      'view': 6483190,
#      'danmaku': 13642,
#      'reply': 5944,
#      'favorite': 101270,
#      'coin': 63984,
#      'share': 6094,
#      'now_rank': 0,
#      'his_rank': 5,
#      'like': 324417,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 6483190,
#      'fav_g': 10,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29876292251,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'season_id': 5265977,
#     'short_link_v2': 'https://b23.tv/BV1FsVSz4EMs',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250509safgeaidzk6guv7tb4yw2mvko_firsti.jpg',
#     'pub_location': '广东',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/1d5dd43f0d252e1324eb0e06a1b75a753876ad5e.jpg',
#     'tidv2': 2001,
#     'tnamev2': '影视解读',
#     'pid_v2': 1001,
#     'pid_name_v2': '影视',
#     'bvid': 'BV1FsVSz4EMs',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '用解说引导观众打开一扇门'},
#    {'aid': 114419438719525,
#     'videos': 1,
#     'tid': 20,
#     'tname': '宅舞',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/a2ccae058b1b56af555b7facabe879f568c56d27.jpg',
#     'title': '听见WO！【BDF2025主题曲】',
#     'pubdate': 1746676800,
#     'ctime': 1745902180,
#     'desc': '哔哩哔哩舞蹈嘉年华(Bilibili Dancing Festival) 迎来第11年！新一个十年已启程！\n——BDF2025主题曲《听见WO!》正式上线啦！\n\n今年，更尽情地做你想成为的自己，一起继续开心地跳舞吧！\n全民挑战活动进行中：https://www.bilibili.com/blackboard/era/MfSXOTONc48Fv9NX.html\n\n演唱：@阿萨Aza  \n编舞：@爱娃利亚一动不动  \n作曲/编曲/混音：@小绵羊magens  \n作词：@大九_LN ',
#     'state': 0,
#     'duration': 233,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 32708657,
#      'name': '舞蹈区小锦鲤',
#      'face': 'https://i2.hdslb.com/bfs/face/46f7a6c5eff4bb44b3962ad9832e3d021eabc82b.jpg'},
#     'stat': {'aid': 114419438719525,
#      'view': 5042488,
#      'danmaku': 731,
#      'reply': 2411,
#      'favorite': 20341,
#      'coin': 6784,
#      'share': 5166,
#      'now_rank': 0,
#      'his_rank': 85,
#      'like': 35035,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 5042488,
#      'fav_g': 4905,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29842671979,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 5423144,
#     'short_link_v2': 'https://b23.tv/BV1qjGyzYEuP',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250508sa2hdn73tvgdcfe9m8oj5pg28_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/9284394287026ccd96d4ef4be9ffe5a2e3d4a392.jpg',
#     'tidv2': 2028,
#     'tnamev2': '宅舞',
#     'pid_v2': 1004,
#     'pid_name_v2': '舞蹈',
#     'bvid': 'BV1qjGyzYEuP',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': 'BDF2025主题曲正式上线啦！'},
#    {'aid': 114495053635353,
#     'videos': 4,
#     'tid': 172,
#     'tname': '手机游戏',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/d6355771a2781fe1d023aa2ff6e14267352fa344.jpg',
#     'title': '《绝区零》雨果EP | My Curse, My Fate「Destin et malédiction」',
#     'pubdate': 1747108800,
#     'ctime': 1747056099,
#     'desc': '现在起，命运在我的脚下俯首\n\n作词：春煦/金秀/粥粥/林樱桃/SmileL/Yuxin Z\n作曲：罗静怡/蔡一琛@TalentUnion/SmileL\n制作人/编曲/混音/母带/其他乐器：宫阁@GONG Studio\n管弦乐团：Budapest Scoring Orchestra\n合声编写：罗静怡\n\n—— 欢迎来到新艾利都！——\n▼ 1.7版本「将眼泪与过往一同埋葬」现已上线！\n限定S级代理人「薇薇安」&「简」现已加入调频&复刻，参与版本限时活动可免费获取全新A级邦布「加班布」！\nbilibili安卓端下',
#     'state': 0,
#     'duration': 1032,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 1636034895,
#      'name': '绝区零',
#      'face': 'https://i0.hdslb.com/bfs/face/049b47e0e73fc5cc1564343bb0aeacce8ae8e6f8.jpg'},
#     'stat': {'aid': 114495053635353,
#      'view': 2361757,
#      'danmaku': 11392,
#      'reply': 14597,
#      'favorite': 82492,
#      'coin': 155372,
#      'share': 33410,
#      'now_rank': 0,
#      'his_rank': 2,
#      'like': 230808,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 2361757,
#      'fav_g': 4514,
#      'like_g': 0},
#     'dynamic': '#绝区零# #将眼泪与过往一同埋葬# #绝区零雨果#\n《绝区零》雨果EP | My Curse, My Fate「Destin et malédiction」',
#     'cid': 29926165314,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1jfE7zrEKd',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250512sa3u6lw454c45hb2hwg1flvt7_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/176379746c31a35e3f3c3bcad31308a442e3502b.jpg',
#     'tidv2': 2016,
#     'tnamev2': '原创音乐',
#     'pid_v2': 1003,
#     'pid_name_v2': '音乐',
#     'bvid': 'BV1jfE7zrEKd',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '感受雨果的人物弧光'},
#    {'aid': 114505925263722,
#     'videos': 1,
#     'tid': 251,
#     'tname': '三农',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/0e26c55825c0409f1efe05826c58b4ee8e2a0656.jpg',
#     'title': '龙兽医单干了，和儿子说拜拜，自己踏上了治愈之路',
#     'pubdate': 1747222122,
#     'ctime': 1747222122,
#     'desc': '',
#     'state': 0,
#     'duration': 652,
#     'mission_id': 4036560,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 414700515,
#      'name': '龙腾虎跃龙兽医',
#      'face': 'https://i0.hdslb.com/bfs/face/697d80194c5a980fa55b9a200ce8b8ecc41ab39a.jpg'},
#     'stat': {'aid': 114505925263722,
#      'view': 4610977,
#      'danmaku': 5016,
#      'reply': 5167,
#      'favorite': 11409,
#      'coin': 24162,
#      'share': 1781,
#      'now_rank': 0,
#      'his_rank': 4,
#      'like': 266074,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 4610977,
#      'fav_g': 751,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29957292810,
#     'dimension': {'width': 1080, 'height': 1920, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV15YEvzpELi',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250514sa3q34s4w72qmp03nedyedsf3_firsti.jpg',
#     'pub_location': '黑龙江',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/daf583b3418f18bb2f5860ed243799f6e942a83f.jpg',
#     'tidv2': 2166,
#     'tnamev2': '农村生活',
#     'pid_v2': 1023,
#     'pid_name_v2': '三农',
#     'bvid': 'BV15YEvzpELi',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '新视角带来新体验'},
#    {'aid': 114465693506382,
#     'videos': 1,
#     'tid': 228,
#     'tname': '人文历史',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/0f5e91bd149fd977e9f148bc001207cdf3f50dc0.jpg',
#     'title': '“人活着，到哪儿还不是做条狗啊？”',
#     'pubdate': 1746608135,
#     'ctime': 1746608136,
#     'desc': '-',
#     'state': 0,
#     'duration': 134,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3546837552204489,
#      'name': '三颗虾仁',
#      'face': 'https://i0.hdslb.com/bfs/face/17dfaeacff40a5df04499faec3666350c0066c84.jpg'},
#     'stat': {'aid': 114465693506382,
#      'view': 5912593,
#      'danmaku': 6429,
#      'reply': 2792,
#      'favorite': 177741,
#      'coin': 145562,
#      'share': 28030,
#      'now_rank': 0,
#      'his_rank': 3,
#      'like': 794242,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 5912593,
#      'fav_g': 13575,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29835463841,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1jEV8zfEM8',
#     'up_from_v2': 35,
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250507sa3u52fu8fap9v73l84scqlw1_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': '',
#     'tidv2': 2154,
#     'tnamev2': '剧情演绎',
#     'pid_v2': 1021,
#     'pid_name_v2': '小剧场',
#     'bvid': 'BV1jEV8zfEM8',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '感染力满分的表演'},
#    {'aid': 114484802752238,
#     'videos': 1,
#     'tid': 171,
#     'tname': '电子竞技',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/ab6a28f9be53dfc4749de13e320104eea3967d4c.jpg',
#     'title': '【超人杯第二季】当五个职业C+对战天禄战队',
#     'pubdate': 1746964800,
#     'ctime': 1746899694,
#     'desc': '',
#     'state': 0,
#     'duration': 3007,
#     'mission_id': 4036606,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 1,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 13663620,
#      'name': '一枪超人CSGO',
#      'face': 'https://i0.hdslb.com/bfs/face/5bf175205ceba5adf1c3f33ce326f5c201cbb04d.jpg'},
#     'stat': {'aid': 114484802752238,
#      'view': 2397212,
#      'danmaku': 27035,
#      'reply': 6566,
#      'favorite': 60642,
#      'coin': 160369,
#      'share': 13470,
#      'now_rank': 0,
#      'his_rank': 5,
#      'like': 179796,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 2397212,
#      'fav_g': 11502,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29918301084,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 4522806,
#     'short_link_v2': 'https://b23.tv/BV1cr5FzxEEH',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250512sa259c7k31y476018p4m93jky_firsti.jpg',
#     'pub_location': '浙江',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/bb5b27e798a5846705f2f47d2e29e4f8a509050a.jpg',
#     'tidv2': 2071,
#     'tnamev2': '射击游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1cr5FzxEEH',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '本期观感极佳！'},
#    {'aid': 114504499201522,
#     'videos': 1,
#     'tid': 212,
#     'tname': '美食侦探',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/484baf613f271f510d8b4c1e3837e96adaf70e3d.jpg',
#     'title': '揭秘！吃一顿国宴是什么体验？',
#     'pubdate': 1747279800,
#     'ctime': 1747200916,
#     'desc': '',
#     'state': 0,
#     'duration': 275,
#     'mission_id': 4033426,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3546888255048212,
#      'name': '特厨隋坡',
#      'face': 'https://i2.hdslb.com/bfs/face/4a6a6e459f71080664d3952957f2eafc02418b85.jpg'},
#     'stat': {'aid': 114504499201522,
#      'view': 7386677,
#      'danmaku': 37617,
#      'reply': 18259,
#      'favorite': 102489,
#      'coin': 355457,
#      'share': 31374,
#      'now_rank': 0,
#      'his_rank': 1,
#      'like': 892894,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 7386677,
#      'fav_g': 857,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29951724830,
#     'dimension': {'width': 2160, 'height': 3840, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV114EezqEm2',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250514sa2bncf38150w983fn7m621g6_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/15cf821f7121397086527139120af04898b26fed.jpg',
#     'tidv2': 2150,
#     'tnamev2': '美食探店',
#     'pid_v2': 1020,
#     'pid_name_v2': '美食',
#     'bvid': 'BV114EezqEm2',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '欢迎特厨归位'},
#    {'aid': 114482487500363,
#     'videos': 1,
#     'tid': 17,
#     'tname': '单机游戏',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/cad5d902763ccd08b29ffa62bd727dfc2f062bec.jpg',
#     'title': '你可能不认识我，但你一定看过我的操作',
#     'pubdate': 1746864541,
#     'ctime': 1746864541,
#     'desc': '',
#     'state': 0,
#     'duration': 114,
#     'mission_id': 4037091,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 509277263,
#      'name': 'SuperMing小洺',
#      'face': 'https://i2.hdslb.com/bfs/face/811cb52416ca922a04d82ad945a294e418d64734.jpg'},
#     'stat': {'aid': 114482487500363,
#      'view': 7880563,
#      'danmaku': 66097,
#      'reply': 3725,
#      'favorite': 278134,
#      'coin': 37799,
#      'share': 9921,
#      'now_rank': 0,
#      'his_rank': 2,
#      'like': 666540,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 7880563,
#      'fav_g': 161433,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29886581255,
#     'dimension': {'width': 2560, 'height': 1920, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1nfVozjErF',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250510sa24q9lghme7ume1zr6sj0r44_firsti.jpg',
#     'pub_location': '广东',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/17fd6533e75aaa016ba6955231b184f0c0caab82.jpg',
#     'tidv2': 2066,
#     'tnamev2': '单机主机类游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1nfVozjErF',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '有一种所有邪修武林秘籍被爆出是同一个天才写的无力感'},
#    {'aid': 114499667433247,
#     'videos': 1,
#     'tid': 228,
#     'tname': '人文历史',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/e11cedebca44217b5c644fdb225ffda8d148342f.jpg',
#     'title': '深度|| 刁民害朕！祭赛国的舍利隐喻，荆棘岭的小人结局',
#     'pubdate': 1747191600,
#     'ctime': 1747126720,
#     'desc': '1、祭赛国的佛宝舍利隐喻什么？\n2、祭赛国的金光宝塔原型是什么？\n3、碧波潭偷塔宝的目的是什么？\n4、二郎神来碧波潭的用意是什么？\n5、二郎神为什么帮着剿灭碧波潭？\n6、佛宝舍利被九叶灵芝温养的隐喻是什么？\n7、荆棘岭的隐喻是什么？\n8、唐僧在荆棘岭的表现有多差？\n9、伪君子是怎样套路人的？',
#     'state': 0,
#     'duration': 3349,
#     'mission_id': 4031781,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 504934876,
#      'name': '渤海小吏',
#      'face': 'https://i1.hdslb.com/bfs/face/60d7ec1a95e5f85e8e5b2c1d49656cbcff176604.jpg'},
#     'stat': {'aid': 114499667433247,
#      'view': 1305214,
#      'danmaku': 11375,
#      'reply': 2697,
#      'favorite': 22309,
#      'coin': 109416,
#      'share': 1793,
#      'now_rank': 0,
#      'his_rank': 11,
#      'like': 93333,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1305214,
#      'fav_g': 470,
#      'like_g': 0},
#     'dynamic': '1、祭赛国的佛宝舍利隐喻什么？\n2、祭赛国的金光宝塔原型是什么？\n3、碧波潭偷塔宝的目的是什么？\n4、二郎神来碧波潭的用意是什么？\n5、二郎神为什么帮着剿灭碧波潭？\n6、佛宝舍利被九叶灵芝温养的隐喻是什么？\n7、荆棘岭的隐喻是什么？\n8、唐僧在荆棘岭的表现有多差？\n9、伪君子是怎样套路人的？',
#     'cid': 29938289700,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'season_id': 4449640,
#     'short_link_v2': 'https://b23.tv/BV1vYEczsEFb',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250513sa3mlpzuuy4h6z0315chc7unz_firsti.jpg',
#     'pub_location': '天津',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/8a208c925f5c78c35c785529ff5b491b56f44fde.jpg',
#     'tidv2': 2090,
#     'tnamev2': '人文历史',
#     'pid_v2': 1010,
#     'pid_name_v2': '知识',
#     'bvid': 'BV1vYEczsEFb',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '“给朕查！吴承恩，他究竟是承谁的恩”'},
#    {'aid': 114466465318644,
#     'videos': 1,
#     'tid': 95,
#     'tname': '数码',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/ac74e636e303085285f594cc8325630e4656972a.jpg',
#     'title': '全球首开Switch 2芯片！性能到底有多强？',
#     'pubdate': 1746621775,
#     'ctime': 1746621775,
#     'desc': '距离Switch 2上市还有一个月，我们居然在闲鱼上提前搞到了一块Switch 2的主板！赶紧把上面的芯片拆下来磨开逆向一下，看看Switch 2的CPU和GPU到底是什么规格，再用FIB-SEM量一量晶体管，确认一下工艺制程。最后用规格相近的PC模拟一下性能！Switch 2到底有多强？一起来看看吧……\n\n更详细的工艺分析可以看Kurnal的视频：BV1RkVbzWE41',
#     'state': 0,
#     'duration': 1528,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 25876945,
#      'name': '极客湾Geekerwan',
#      'face': 'http://i1.hdslb.com/bfs/face/d0f7a7ee34a4a45c8390eb3a07e4d7f2d70bae91.jpg'},
#     'stat': {'aid': 114466465318644,
#      'view': 2853895,
#      'danmaku': 19162,
#      'reply': 17253,
#      'favorite': 49601,
#      'coin': 190650,
#      'share': 48181,
#      'now_rank': 0,
#      'his_rank': 1,
#      'like': 226119,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 2853895,
#      'fav_g': 1107,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29973481614,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1qEVazqEv3',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250515sa3sryu7d9v9o331x813wuypg_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/abf223fbaa81131e527bc95f71a308974cb5829b.jpg',
#     'tidv2': 2105,
#     'tnamev2': '科技数码综合',
#     'pid_v2': 1012,
#     'pid_name_v2': '科技数码',
#     'bvid': 'BV1qEVazqEv3',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': 'Switch 2到底有多强？'},
#    {'aid': 114492570603023,
#     'videos': 1,
#     'tid': 215,
#     'tname': '美食记录',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/f4b870f11a8171a818443cbce4094983e6d7e27f.jpg',
#     'title': '天津早点吃法教程之方便面篇',
#     'pubdate': 1747018324,
#     'ctime': 1747018325,
#     'desc': '-',
#     'state': 0,
#     'duration': 462,
#     'mission_id': 4033426,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3546594741848906,
#      'name': '团团的一家',
#      'face': 'https://i2.hdslb.com/bfs/face/f578dc23bbfbbfd845c7800b763f7ec872269e28.jpg'},
#     'stat': {'aid': 114492570603023,
#      'view': 3201760,
#      'danmaku': 6614,
#      'reply': 7609,
#      'favorite': 34569,
#      'coin': 35198,
#      'share': 55531,
#      'now_rank': 0,
#      'his_rank': 7,
#      'like': 215627,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 3201760,
#      'fav_g': 7,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29917250859,
#     'dimension': {'width': 1080, 'height': 1920, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1vVELzeEpZ',
#     'up_from_v2': 36,
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250512sa12t7mjjmxkyou1nkcbe94o6_firsti.jpg',
#     'pub_location': '天津',
#     'cover43': '',
#     'tidv2': 2152,
#     'tnamev2': '美食记录',
#     'pid_v2': 1020,
#     'pid_name_v2': '美食',
#     'bvid': 'BV1vVELzeEpZ',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '“王爷不更新的日子里我简直就是在乱吃”'},
#    {'aid': 114505220624919,
#     'videos': 1,
#     'tid': 207,
#     'tname': '财经商业',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/4051455e2a78c9592280531017a10550a5c25d6a.jpg',
#     'title': '全球第一网红，一边撒钱，一边赚钱，how？',
#     'pubdate': 1747215919,
#     'ctime': 1747211875,
#     'desc': 'YouTube上订阅最多的频道：Mr Beast野兽先生，每段视频的平均播放量超2亿，每段视频的制作成本达到了惊人的400万美元。\n小Lin这次拿到了独家采访Mr Beast的机会，今天咱们就来一起探究一下世界第一网红的秘密。',
#     'state': 0,
#     'duration': 1153,
#     'mission_id': 4034146,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 1,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 520819684,
#      'name': '小Lin说',
#      'face': 'https://i1.hdslb.com/bfs/face/cf895b86c955e4ce62b28b3c2bb5bbc77f9fd410.jpg'},
#     'stat': {'aid': 114505220624919,
#      'view': 3586750,
#      'danmaku': 4417,
#      'reply': 3223,
#      'favorite': 63727,
#      'coin': 23330,
#      'share': 5100,
#      'now_rank': 0,
#      'his_rank': 10,
#      'like': 109281,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 3586750,
#      'fav_g': 40884,
#      'like_g': 0},
#     'dynamic': '这可是全球第一大网红第一次接受中文博主访谈哦～\xa0来看看小Lin拿到了什么独家信息[doge][doge]',
#     'cid': 29954280092,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV19EEizDEc4',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250514sa3kg3cw25fj0n735lbjdguhu_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/b994acaafcf90157cdecdefc5039d163a410bd39.jpg',
#     'tidv2': 2087,
#     'tnamev2': '商业财经',
#     'pid_v2': 1010,
#     'pid_name_v2': '知识',
#     'bvid': 'BV19EEizDEc4',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '小Lin说揭秘野兽先生的赚钱秘诀'},
#    {'aid': 114494399319911,
#     'videos': 1,
#     'tid': 124,
#     'tname': '社科·法律·心理',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/b5f48af479a95c88472258a724d2e5e58dd353eb.jpg',
#     'title': '印巴迷雾：导弹横飞之后，皆称大获全胜',
#     'pubdate': 1747046053,
#     'ctime': 1747046054,
#     'desc': '',
#     'state': 0,
#     'duration': 932,
#     'mission_id': 4036041,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 346563107,
#      'name': '波士顿圆脸',
#      'face': 'https://i2.hdslb.com/bfs/face/f8f0fc4114bb06a87481abe12faa006a383cbe6d.jpg'},
#     'stat': {'aid': 114494399319911,
#      'view': 1803350,
#      'danmaku': 7174,
#      'reply': 3112,
#      'favorite': 6128,
#      'coin': 7543,
#      'share': 1054,
#      'now_rank': 0,
#      'his_rank': 33,
#      'like': 87178,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1803350,
#      'fav_g': 0,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29924131066,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1h8EJzuEhY',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250512saoxle9ngwdse018zwf56fy9p_firsti.jpg',
#     'pub_location': '江西',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/fa665779580ce1a9c54dbfa2d94362632d38123e.jpg',
#     'tidv2': 2081,
#     'tnamev2': '海外资讯',
#     'pid_v2': 1009,
#     'pid_name_v2': '资讯',
#     'bvid': 'BV1h8EJzuEhY',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '圆脸解析印巴冲突'},
#    {'aid': 114478410636974,
#     'videos': 1,
#     'tid': 17,
#     'tname': '单机游戏',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/9a292fc54eb880e23aec4de21dd9366afa90c255.jpg',
#     'title': '这就是来自盾哥抓钩的救赎嘛？？',
#     'pubdate': 1746802129,
#     'ctime': 1746802130,
#     'desc': '',
#     'state': 0,
#     'duration': 184,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3546875066059052,
#      'name': '高司令-速凌电竞',
#      'face': 'https://i2.hdslb.com/bfs/face/8119a560bc06a6436665606570a7332cb0756a89.jpg'},
#     'stat': {'aid': 114478410636974,
#      'view': 4343585,
#      'danmaku': 1888,
#      'reply': 4843,
#      'favorite': 93874,
#      'coin': 55307,
#      'share': 15191,
#      'now_rank': 0,
#      'his_rank': 8,
#      'like': 268785,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 4343585,
#      'fav_g': 36811,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29875309191,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1XrVSzyEHL',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250509sa1gf58zie2l9c6gp872uyt0m_firsti.jpg',
#     'pub_location': '辽宁',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/7e6cce9974c5e5f0bcda75408047a35d42b3e98e.jpg',
#     'tidv2': 2037,
#     'tnamev2': '同人动画',
#     'pid_v2': 1005,
#     'pid_name_v2': '二次元',
#     'bvid': 'BV1XrVSzyEHL',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '剧情最后还升华了，豪看'},
#    {'aid': 114510958499544,
#     'videos': 8,
#     'tid': 172,
#     'tname': '手机游戏',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/b4a47fe7555ee1b45451666f617990b826e19d9c.jpg',
#     'title': '【众生行记】MT-S-1至MT-S-5突袭 摆完挂机 简单好抄',
#     'pubdate': 1747299195,
#     'ctime': 1747299195,
#     'desc': '干员均专三60级带1级模组，歌蒂3级X模组（给乌尔比安减伤回血，很重要）\n本视频为为懒人向挂机流攻略，不排斥手动开启的技能但少用，视频里大多数情况都是携带挂机技能的快速摆完的打法，少部分难打的关卡会选择简单好抄的手动打法，用一些决战技等手动技能，非低配攻略。\n\n视频里常用的干员及技能:\nps：视频绝大多数情况都是用的都是永续/点燃/强力击类的挂机技能，手动技能用的非常少，但用的手动技能基本都是可汗玩家很常用的技能，标记出来方便大家专精\n【先锋】桃金娘1、德克萨斯1、推进之王2、风笛2、伊内斯123\n【近卫',
#     'state': 0,
#     'duration': 1910,
#     'mission_id': 4037291,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 31009079,
#      'name': '萧然Q',
#      'face': 'https://i2.hdslb.com/bfs/face/dca58d7a5a1cd34b8bd152c0bf8784c1555dcd30.jpg'},
#     'stat': {'aid': 114510958499544,
#      'view': 4537100,
#      'danmaku': 3508,
#      'reply': 6617,
#      'favorite': 10405,
#      'coin': 52746,
#      'share': 2796,
#      'now_rank': 0,
#      'his_rank': 45,
#      'like': 62779,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 4537100,
#      'fav_g': 5,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29971385881,
#     'dimension': {'width': 2560, 'height': 1440, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1p5Eyz4E8u',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250515a21jqi5kv93a1y11okkxipm8r_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': '',
#     'tidv2': 2064,
#     'tnamev2': '单人RPG游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1p5Eyz4E8u',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '伟大的萧然带着他的作业来了'},
#    {'aid': 114498174263181,
#     'videos': 1,
#     'tid': 65,
#     'tname': '网络游戏',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/a08b9dd031d0e704900e0b04236fb3e223201ec1.jpg',
#     'title': '悠悠凉州彻 | 河西新篇章「凉州」即将上线！',
#     'pubdate': 1747103801,
#     'ctime': 1747103801,
#     'desc': '自古以来，凉州就是连通西域与汉家的门扉。\n\n上百年的战争与商贸催生出了独特的风土人情，让这里变成故事发生的绝佳舞台。关乎荣耀、使命、自由、生死……当故事交织在这里，即是属于凉州的百年孤独。\n\n5月16日，《燕云十六声》新版本「悠悠凉州彻」即将上线。且待游侠亲自翻开新篇，直面凉州的风雪与剑光！',
#     'state': 0,
#     'duration': 102,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 1567141152,
#      'name': '燕云十六声官方',
#      'face': 'https://i0.hdslb.com/bfs/face/4a2550ebcd14c456bce4ad423d35082afde073f6.jpg'},
#     'stat': {'aid': 114498174263181,
#      'view': 1736638,
#      'danmaku': 695,
#      'reply': 3838,
#      'favorite': 3813,
#      'coin': 5207,
#      'share': 4333,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 23321,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1736638,
#      'fav_g': 910,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29933373897,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1vp7oz1ExP',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250513sa343ov7szcud72rddkzbia53_firsti.jpg',
#     'pub_location': '浙江',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/7ee4619f08a1d24ef1b9264184aa667c679c83b2.jpg',
#     'tidv2': 2066,
#     'tnamev2': '单机主机类游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1vp7oz1ExP',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '属于凉州的百年孤独'},
#    {'aid': 114478930724555,
#     'videos': 1,
#     'tid': 176,
#     'tname': '汽车生活',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/159d6b1410c22bec646b9563eb3a9175936ae2cb.jpg',
#     'title': '450万粉丝科技区UP主开什么车？极客湾飘哥爱车曝光！',
#     'pubdate': 1746871500,
#     'ctime': 1746810134,
#     'desc': '',
#     'state': 0,
#     'duration': 1662,
#     'mission_id': 4036196,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 1,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 86439234,
#      'name': 'Upspeed盛嘉成',
#      'face': 'https://i0.hdslb.com/bfs/face/f4920f78b6d30a5f4b21e2026924bd99bfb50f58.jpg'},
#     'stat': {'aid': 114478930724555,
#      'view': 1117084,
#      'danmaku': 4545,
#      'reply': 2039,
#      'favorite': 7099,
#      'coin': 21397,
#      'share': 1943,
#      'now_rank': 0,
#      'his_rank': 66,
#      'like': 79571,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1117084,
#      'fav_g': 354,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29874980191,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 3714,
#     'short_link_v2': 'https://b23.tv/BV159VUzmEfh',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250509sa1zxag40n3e0bp39n1q5gh88_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/83d424616d29ca394c64404148c577794c065f00.jpg',
#     'tidv2': 2107,
#     'tnamev2': '汽车文化',
#     'pid_v2': 1013,
#     'pid_name_v2': '汽车',
#     'bvid': 'BV159VUzmEfh',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '飘哥对车的专业程度好在线！'},
#    {'aid': 114511193444175,
#     'videos': 1,
#     'tid': 124,
#     'tname': '社科·法律·心理',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/ac5b5e3f6b86366faf2a7b94388cbac021860f7e.jpg',
#     'title': '上乘赢学在印度——莫迪宣布大胜！全国连庆10天',
#     'pubdate': 1747303092,
#     'ctime': 1747302716,
#     'desc': '',
#     'state': 0,
#     'duration': 1077,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 703186600,
#      'name': '麻薯波比呀',
#      'face': 'https://i1.hdslb.com/bfs/face/826f6c258199edc87d5722a56e8a8f963686dbba.jpg'},
#     'stat': {'aid': 114511193444175,
#      'view': 3365524,
#      'danmaku': 15433,
#      'reply': 7334,
#      'favorite': 12875,
#      'coin': 17538,
#      'share': 6078,
#      'now_rank': 0,
#      'his_rank': 15,
#      'like': 147109,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 3365524,
#      'fav_g': 4,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29972169688,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'season_id': 2190989,
#     'short_link_v2': 'https://b23.tv/BV1FeECzREoK',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250515sa3qpl8vvdy69xg34kap9sl9r_firsti.jpg',
#     'pub_location': '江苏',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/dca4f5b3b11a0746d9629015f235ab9a24376e6e.jpg',
#     'tidv2': 2089,
#     'tnamev2': '时政解读',
#     'pid_v2': 1010,
#     'pid_name_v2': '知识',
#     'bvid': 'BV1FeECzREoK',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '到底谁赢了？'},
#    {'aid': 114482588160093,
#     'videos': 1,
#     'tid': 182,
#     'tname': '影视杂谈',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/38e54bf6e7ca22f59e9ae4c778dcf1b15b29d2e5.jpg',
#     'title': '“小丑”如何成为总统？深度拆解特朗普的媒体形象营造！',
#     'pubdate': 1746875051,
#     'ctime': 1746869031,
#     'desc': '其实，比起特朗普差劲的经济政策、混乱的管理能力、滑稽的政治头脑，这个人身上真正值得拆解的，是他对于大众媒体无比娴熟的操纵与玩弄，是哪怕他曾多次公开侮辱女性、大搞种族分裂、言行前后不一致、素质极其低下、总进行人身攻击、做出各种啼笑皆非的离谱举动，他与他幕后的团队，却总能是用特定的诡辩话术、巧妙准备的媒体策略、严格设计的手势与定位、层层包装递进的大众传播形象，让特朗普成为了美国建国以来首位真人秀总统，并且在2024年二次竞选成功。\n\t\n\t多年来，特朗普究竟是如何通过大众媒体组合拳：演讲、推特、短视频、照片、话',
#     'state': 0,
#     'duration': 1365,
#     'mission_id': 4035755,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3461574557698362,
#      'name': 'Claire的编辑室',
#      'face': 'https://i0.hdslb.com/bfs/face/58aa8a3002c4c32eb5ed5734244c3f2569d6e5f8.jpg'},
#     'stat': {'aid': 114482588160093,
#      'view': 1825493,
#      'danmaku': 8065,
#      'reply': 3166,
#      'favorite': 55759,
#      'coin': 36462,
#      'share': 7224,
#      'now_rank': 0,
#      'his_rank': 13,
#      'like': 139972,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1825493,
#      'fav_g': 14,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29888480241,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'season_id': 1323912,
#     'short_link_v2': 'https://b23.tv/BV1pdVozEEXj',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250510sa3lv2n91jxr20i37h51h53w5_firsti.jpg',
#     'pub_location': '天津',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/1a7d662717ec52756cfad27484e732659d422e6a.jpg',
#     'tidv2': 2001,
#     'tnamev2': '影视解读',
#     'pid_v2': 1001,
#     'pid_name_v2': '影视',
#     'bvid': 'BV1pdVozEEXj',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '质量爆炸的深度解读'},
#    {'aid': 114505304507929,
#     'videos': 1,
#     'tid': 138,
#     'tname': '搞笑',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/6b177fff0929dbc927b7fcc3fa2def7460067ebc.jpg',
#     'title': '《小杨有约14#》：小潮院长父亲',
#     'pubdate': 1747213306,
#     'ctime': 1747212944,
#     'desc': '小杨有约第十四期！\n应该是本系列最特殊的一位嘉宾了！\n视频内容纯属娱乐，不要当真～\n你希望在节目里看到谁呢？\n欢迎关注！一键三连也拜托了！！',
#     'state': 0,
#     'duration': 567,
#     'mission_id': 4034101,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3178005,
#      'name': '小杨Johnson',
#      'face': 'https://i0.hdslb.com/bfs/face/d92e258f177254ff9307630e5c373a350fe186e7.jpg'},
#     'stat': {'aid': 114505304507929,
#      'view': 1832232,
#      'danmaku': 7145,
#      'reply': 2213,
#      'favorite': 42280,
#      'coin': 67226,
#      'share': 2612,
#      'now_rank': 0,
#      'his_rank': 6,
#      'like': 167291,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1832232,
#      'fav_g': 10824,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29950807769,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV128EizVEts',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250514a23vmq8eeriubg43e8irifens_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/a6061c55620412b2189d9a64245cbf02bb143885.jpg',
#     'tidv2': 2156,
#     'tnamev2': 'UP主小综艺',
#     'pid_v2': 1021,
#     'pid_name_v2': '小剧场',
#     'bvid': 'BV128EizVEts',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '本系列最特殊的一位嘉宾'},
#    {'aid': 114480776218660,
#     'videos': 1,
#     'tid': 239,
#     'tname': '家居房产',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/23b4d52e2d81017ade7c2610e7951c8eea424148.jpg',
#     'title': '最开始只是因为家里的沙发被猫霸占了…',
#     'pubdate': 1746849600,
#     'ctime': 1746838182,
#     'desc': '-',
#     'state': 0,
#     'duration': 129,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 313614629,
#      'name': '柴总在忙',
#      'face': 'https://i2.hdslb.com/bfs/face/30d6617758c3878733674ed228297e8c2b38abd2.jpg'},
#     'stat': {'aid': 114480776218660,
#      'view': 5583388,
#      'danmaku': 996,
#      'reply': 1504,
#      'favorite': 74501,
#      'coin': 22433,
#      'share': 5670,
#      'now_rank': 0,
#      'his_rank': 10,
#      'like': 318582,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 5583388,
#      'fav_g': 23436,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29880225001,
#     'dimension': {'width': 1080, 'height': 1920, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1pyVXzgEQX',
#     'up_from_v2': 9,
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250510sa18b85wpda07r39tq9xdar4z_firsti.jpg',
#     'pub_location': '广东',
#     'cover43': '',
#     'tidv2': 2167,
#     'tnamev2': '猫',
#     'pid_v2': 1024,
#     'pid_name_v2': '动物',
#     'bvid': 'BV1pyVXzgEQX',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': 'UP的家好像童话书，每一间都是童年的切片'},
#    {'aid': 114458596739076,
#     'videos': 1,
#     'tid': 233,
#     'tname': '极客DIY',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/c05728068846622a363fcf34574c263bdaec13bb.jpg',
#     'title': '《异环》「收容测试」招募PV丨即刻开始收容！',
#     'pubdate': 1747274400,
#     'ctime': 1746499636,
#     'desc': '《异环》「收容测试」招募现已开启，立刻前往>>>https://t.bilibili.com/1067024490902323203\n\n好久不见~鉴定师。你不在的日子里，海特洛发生了好多事！\n但是没关系，因为一切异常，就是日常！\n——现在，该你登场啦！\n\n▼ 制作名单\n制作/作曲/编曲：ChiliChill\n演唱：ChiliChill\n作词：ChiliChill',
#     'state': 0,
#     'duration': 194,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3546636978489848,
#      'name': '异环',
#      'face': 'https://i2.hdslb.com/bfs/face/5790579b2517b237df23d765719157ddf3537091.jpg'},
#     'stat': {'aid': 114458596739076,
#      'view': 5218060,
#      'danmaku': 3974,
#      'reply': 13487,
#      'favorite': 42175,
#      'coin': 37098,
#      'share': 29374,
#      'now_rank': 0,
#      'his_rank': 3,
#      'like': 169406,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 5218060,
#      'fav_g': 9701,
#      'like_g': 0},
#     'dynamic': '#异环# #异环二测招募开启# #异环收容测试#\n好久不见~鉴定师。你不在的日子里，海特洛发生了好多事！\n但是没关系，因为一切异常，就是日常！\n——现在，该你登场啦！\n超自然都市开放世界RPG《异环》预约活动现已开启，参与即有机会获取测试资格、PS5pro游戏机等惊喜好礼！>>>https://yh.biligame.com/srcsyy/h5',
#     'cid': 29949560628,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1t7VyzdEQa',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250514sa3pqqr5vz5skz82pc5lchvh8_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/903975ce1bb7a919874d8309d00a981f9de89ebd.jpg',
#     'tidv2': 2079,
#     'tnamev2': '其他游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1t7VyzdEQa',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '好久不见，鉴定师'},
#    {'aid': 114495557017492,
#     'videos': 1,
#     'tid': 182,
#     'tname': '影视杂谈',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/14127c4d387f1030422091df264c2f9734c88f35.jpg',
#     'title': '口碑最烂！黑人队长还是不行！千字赤石《美国队长4》',
#     'pubdate': 1747130400,
#     'ctime': 1747065450,
#     'desc': '文案、剪輯、配音等：BA\n電影立項與劇本閱讀整理： \ufeff\ufeff@字母编辑',
#     'state': 0,
#     'duration': 1669,
#     'mission_id': 4034775,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
# ...
#     'owner': {'mid': 3546719514003582,
#      'name': 'RED_OFFICIAL_',
#      'face': 'https://i0.hdslb.com/bfs/face/4ef2d76ce448667309ea3b62fac290d9b507677b.jpg'},
#     'stat': {'aid': 114476615540609,
#      'view': 1586886,
#      'danmaku': 16939,
#      'reply': 21774,
#      'favorite': 27660,
#      'coin': 63899,
#      'share': 29552,
#      'now_rank': 0,
#      'his_rank': 40,
#      'like': 90918,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1586886,
#      'fav_g': 595,
#      'like_g': 0},
#     'dynamic': 'R.E.D主打歌《三彩》MV正式上线！\n\n在钻石般璀璨的釉色中，完成从东方古韵到未来美学的华丽转身。这既是一场传统符号的时尚起义，更是每个不甘被定义的灵魂发出的淬火宣言。  \n',
#     'cid': 29866985589,
#     'dimension': {'width': 3240, 'height': 2160, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1Me5VzBET1',
#     'up_from_v2': 36,
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250509sa1ew7avjpew7qz2720vafpvx_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': '',
#     'tidv2': 2017,
#     'tnamev2': 'MV',
#     'pid_v2': 1003,
#     'pid_name_v2': '音乐',
#     'bvid': 'BV1Me5VzBET1',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '国内女团的顶级表现力'},
#    {'aid': 114494516756744,
#     'videos': 4,
#     'tid': 172,
#     'tname': '手机游戏',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/b180339daa53056b2fc3dba162ed4b1c703e3c41.jpg',
#     'title': '《二重螺旋》致明日招募PV丨展望黎明前',
#     'pubdate': 1747101600,
#     'ctime': 1747047765,
#     'desc': '伫立于故事的原点，展望黎明前的地平线——\n而后，就此出发。\n\n✦「致明日测试」招募开启，欢迎各位狩月人完成问卷填写、参与报名：https://dna.biligame.com/xyycj/h5\n✦ 游戏预约：https://dna.biligame.com/yycj',
#     'state': 0,
#     'duration': 412,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 3461571554577304,
#      'name': '二重螺旋',
#      'face': 'https://i1.hdslb.com/bfs/face/aef25ce323e2a63951962b76db0d61b24d0aa1a4.jpg'},
#     'stat': {'aid': 114494516756744,
#      'view': 2818651,
#      'danmaku': 828,
#      'reply': 2521,
#      'favorite': 27924,
#      'coin': 19703,
#      'share': 3688,
#      'now_rank': 0,
#      'his_rank': 5,
#      'like': 70498,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 2818651,
#      'fav_g': 1122,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29920333140,
#     'dimension': {'width': 3840, 'height': 1620, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1QUEEzTE62',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250512sa3cfrmhog96hah1np7mlhhzp_firsti.jpg',
#     'pub_location': '浙江',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/80a6ef1fc4816f6bdec6cc84f9ad29989387ea1e.jpg',
#     'tidv2': 2064,
#     'tnamev2': '单人RPG游戏',
#     'pid_v2': 1008,
#     'pid_name_v2': '游戏',
#     'bvid': 'BV1QUEEzTE62',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '伫立于故事的原点，展望黎明前的地平线'},
#    {'aid': 114477085237200,
#     'videos': 1,
#     'tid': 215,
#     'tname': '美食记录',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/fb80616b93d46678ece7bef54d543ad886313c26.jpg',
#     'title': '挪威黄金海胆北极贝泛滥！芬兰家人跨国捡爆桶太炸裂！中式海鲜盛宴蒜蓉爆炒花式做法震撼芬兰人！',
#     'pubdate': 1746783768,
#     'ctime': 1746783564,
#     'desc': '挪威北冰洋黄金海胆北极贝泛滥简直太震撼！\n堆成山的海胆，满沙滩的北极贝还有数不尽的青口贝鸟哈，芬兰一家人跨国直奔北冰洋赶海，这架势简直惊到我们在海滩欢呼！大伯侄子海胆现捡现吃太夸张，海钓鳕鱼轻松捡爆桶全家欢呼雀跃！满车的海鲜蒜蓉爆炒清蒸各种花式吃法征服全家，新老客人吃到开心到疯狂干杯！赶海真的太好玩，在零下10度北冰洋赶海更是太炸裂，虽然超累但下次还要去！哈哈哈哈哈希望大家喜欢看这期视频！爱你们！\n\n*本视频含合作【妙界】谢谢大家的支持，我们才有合作的机会！',
#     'state': 0,
#     'duration': 1243,
#     'mission_id': 4033426,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 323024456,
#      'name': '雨琪在芬兰',
#      'face': 'https://i2.hdslb.com/bfs/face/59f832f5fdb0a01391339ce842e4dae00c2f504a.jpg'},
#     'stat': {'aid': 114477085237200,
#      'view': 1630271,
#      'danmaku': 7181,
#      'reply': 1470,
#      'favorite': 16151,
#      'coin': 71061,
#      'share': 1711,
#      'now_rank': 0,
#      'his_rank': 34,
#      'like': 128311,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1630271,
#      'fav_g': 4928,
#      'like_g': 0},
#     'dynamic': '#美食vlog连载企划#跨国超级大制作来啦！挪威黄金海胆北极贝泛滥简直太震撼！堆成山的海胆，满沙滩的北极贝还有数不尽的青口贝鸟哈，芬兰一家人跨国赶海捡到手软！这架势简直惊到我们在海滩欢呼！大伯侄子海胆现捡现吃太夸张，海钓鳕鱼轻松捡爆桶全家欢呼雀跃！满车的海鲜蒜蓉爆炒清蒸各种花式吃法征服全家，新老客人吃到开心到疯狂干杯！赶海真的太好玩，在零下10度北冰洋赶海更是太炸裂，虽然超累但下次还要去！哈哈哈哈哈希望大家喜欢看这期视频！爱你们！',
#     'cid': 29868294287,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 13282,
#     'short_link_v2': 'https://b23.tv/BV11C5LzuE7x',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250509ad18wsfsuwkh8hka5qpl26mzi_firsti.jpg',
#     'pub_location': '芬兰',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/fd46a0aa95b1fe285e278a76444b78f15c1a2583.jpg',
#     'tidv2': 2163,
#     'tnamev2': '赶海捕鱼',
#     'pid_v2': 1023,
#     'pid_name_v2': '三农',
#     'bvid': 'BV11C5LzuE7x',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '芬兰一家人跨国直奔北冰洋赶海'},
#    {'aid': 114500774662190,
#     'videos': 1,
#     'tid': 253,
#     'tname': '动漫杂谈',
#     'copyright': 1,
#     'pic': 'http://i2.hdslb.com/bfs/archive/443839e966399b2dbdd1f44473451bad2197fd81.jpg',
#     'title': '一个铁片卖到五位数？这也太赚钱了吧【阅片无数SP】',
#     'pubdate': 1747216800,
#     'ctime': 1747143447,
#     'desc': '做这期视频还是刷了不少人脉，得到了一些奇妙的内容，希望对大伙有用',
#     'state': 0,
#     'duration': 1066,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 14110780,
#      'name': '凉风Kaze',
#      'face': 'https://i1.hdslb.com/bfs/face/e0cc906bb531195e9ee9f3b575effdd2b056eaea.jpg'},
#     'stat': {'aid': 114500774662190,
#      'view': 1578526,
#      'danmaku': 2069,
#      'reply': 4258,
#      'favorite': 10990,
#      'coin': 3857,
#      'share': 1881,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 46806,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1578526,
#      'fav_g': 5014,
#      'like_g': 0},
#     'dynamic': '做这期视频还是刷了不少人脉，得到了一些奇妙的内容，希望对大伙有用',
#     'cid': 29942874807,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'season_id': 5244474,
#     'short_link_v2': 'https://b23.tv/BV1x5EAzLEGe',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250513safosbk3u4ourb1d0kebmue2n_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/aca128d9c532735f68ab04f74af23e69ec0fa101.jpg',
#     'tidv2': 2040,
#     'tnamev2': '二次元线下',
#     'pid_v2': 1005,
#     'pid_name_v2': '二次元',
#     'bvid': 'BV1x5EAzLEGe',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '谷子经济为何如此火爆？'},
#    {'aid': 114472756780905,
#     'videos': 1,
#     'tid': 47,
#     'tname': '同人·手书',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/f06ee4c25526a502b8c2158c658e0d93174bdf19.jpg',
#     'title': '【大鸣王潮1566】我们需要更多的卡',
#     'pubdate': 1746715844,
#     'ctime': 1746715844,
#     'desc': '-',
#     'state': 0,
#     'duration': 183,
#     'mission_id': 4036584,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 293187959,
#      'name': '寞桀緣才',
#      'face': 'https://i2.hdslb.com/bfs/face/6b4baaf04d1ba4f5e36368c14a3315833b54e481.jpg'},
#     'stat': {'aid': 114472756780905,
#      'view': 1410524,
#      'danmaku': 6498,
#      'reply': 3802,
#      'favorite': 17409,
#      'coin': 41159,
#      'share': 7634,
#      'now_rank': 0,
#      'his_rank': 41,
#      'like': 113015,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1410524,
#      'fav_g': 669,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29858005776,
#     'dimension': {'width': 1920, 'height': 940, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV17T5uz6ETj',
#     'up_from_v2': 8,
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250508sa1ycvstgaotdoq1xup56lyqm_firsti.jpg',
#     'pub_location': '河北',
#     'cover43': '',
#     'tidv2': 2037,
#     'tnamev2': '同人动画',
#     'pid_v2': 1005,
#     'pid_name_v2': '二次元',
#     'bvid': 'BV17T5uz6ETj',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '创作状态离神很近，但离人又太远'},
#    {'aid': 114471213342611,
#     'videos': 1,
#     'tid': 71,
#     'tname': '综艺',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/18deb83022eae3cfee8e7f358e0ab895772cd9fb.jpg',
#     'title': '刘奕畅四处发疯！李沐宸没人伺候走不动路！少爷公主来《无限超越班》微服私访来了',
#     'pubdate': 1746700200,
#     'ctime': 1746692873,
#     'desc': '',
#     'state': 0,
#     'duration': 919,
#     'mission_id': 4034415,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 8365699,
#      'name': '郭本尼',
#      'face': 'https://i1.hdslb.com/bfs/face/3ce90cff218ea393de8487cfa38a878a1ba168a2.jpg'},
#     'stat': {'aid': 114471213342611,
#      'view': 1212003,
#      'danmaku': 2400,
#      'reply': 682,
#      'favorite': 6372,
#      'coin': 1381,
#      'share': 1020,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 82311,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 1212003,
#      'fav_g': 160,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29850929080,
#     'dimension': {'width': 2338, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV14n5NzLEQn',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250508a23jopy63b0d7um1mbjanarbf_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i2.hdslb.com/bfs/archive/dabc10d4dd099e8573003b88cd1f03af0c9de536.jpg',
#     'tidv2': 2009,
#     'tnamev2': '娱乐评论',
#     'pid_v2': 1002,
#     'pid_name_v2': '娱乐',
#     'bvid': 'BV14n5NzLEQn',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '郭本尼辣评无限超越班'},
#    {'aid': 114501546415520,
#     'videos': 1,
#     'tid': 207,
#     'tname': '财经商业',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/a1345079021dbed24bae992d49a6006bdd46a8b1.jpg',
#     'title': '【巫师】关税战04：回档背后是赢赢赢赢赢，那谁输了',
#     'pubdate': 1747155698,
#     'ctime': 1747155698,
#     'desc': '',
#     'state': 0,
#     'duration': 560,
#     'mission_id': 4034146,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 472747194,
#      'name': '巫师财经',
#      'face': 'https://i0.hdslb.com/bfs/face/c518dc95663850d075a90897de617cc634151f7a.jpg'},
#     'stat': {'aid': 114501546415520,
#      'view': 624024,
#      'danmaku': 970,
#      'reply': 1320,
#      'favorite': 4657,
#      'coin': 6719,
#      'share': 1442,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 25547,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 624024,
#      'fav_g': 2,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 29946413801,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1wZEczMEDf',
#     'first_frame': 'http://i1.hdslb.com/bfs/storyff/n250514sa2fhmpe6k2bclu29useu7ci8_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/99da3902ca0436f6889dcf6b685a9fdb0eea00e6.jpg',
#     'tidv2': 2087,
#     'tnamev2': '商业财经',
#     'pid_v2': 1010,
#     'pid_name_v2': '知识',
#     'bvid': 'BV1wZEczMEDf',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '带你看懂关税战的最新动向'},
#    {'aid': 114482487566084,
#     'videos': 1,
#     'tid': 250,
#     'tname': '出行',
#     'copyright': 1,
#     'pic': 'http://i0.hdslb.com/bfs/archive/bd18263d402159904fe799359c23c3bb249b1588.jpg',
#     'title': '全球唯一建在水上的城市，威尼斯值得去吗？！',
#     'pubdate': 1746867722,
#     'ctime': 1746864501,
#     'desc': '3天2晚从不同角度测评威尼斯，这座历史长达15世纪的意大利水城，除了全球唯一的“交通系统”外，它还有什么独特魅力呢？',
#     'state': 0,
#     'duration': 1414,
#     'mission_id': 4034168,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 1,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 644255470,
#      'name': '杰克小兔',
#      'face': 'https://i1.hdslb.com/bfs/face/013a96a5d1dc54a152e87816776eaf88997ea5e7.jpg'},
#     'stat': {'aid': 114482487566084,
#      'view': 870610,
#      'danmaku': 7182,
#      'reply': 1315,
#      'favorite': 6919,
#      'coin': 13463,
#      'share': 1771,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 28320,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 870610,
#      'fav_g': 2042,
#      'like_g': 0},
#     'dynamic': '全球唯一建在水上的城市，威尼斯值得去吗？！',
#     'cid': 29885927067,
#     'dimension': {'width': 3840, 'height': 2160, 'rotate': 0},
#     'season_id': 1836612,
#     'short_link_v2': 'https://b23.tv/BV1rfVozjELk',
#     'first_frame': 'http://i0.hdslb.com/bfs/storyff/n250510sa10jnczd6cjbmy32ug86eiqw_firsti.jpg',
#     'pub_location': '上海',
#     'cover43': 'http://i1.hdslb.com/bfs/archive/0990e7041ab2e036bb25df18769e8fa35fff8581.jpg',
#     'tidv2': 2159,
#     'tnamev2': '旅游攻略',
#     'pid_v2': 1022,
#     'pid_name_v2': '旅游出行',
#     'bvid': 'BV1rfVozjELk',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '3天2晚从不同角度测评威尼斯'},
#    {'aid': 114511981843933,
#     'videos': 1,
#     'tid': 124,
#     'tname': '社科·法律·心理',
#     'copyright': 1,
#     'pic': 'http://i1.hdslb.com/bfs/archive/7048e248ae75ad49a5c14fa0f41e4f024b12be42.jpg',
#     'title': '【罗翔】张三被骗：护肤品广告宣传“一秒回春”有人管吗？',
#     'pubdate': 1747366200,
#     'ctime': 1747315002,
#     'desc': '很高兴能有机会学习关于化妆品的法律问题。今天和大家聊一聊什么是化妆品的虚假宣传。化妆品能宣传的功效有哪些？需要提供什么样的依据？哪些不能宣传？我们为什么使用化妆品，不仅为了悦人，更是为了悦己，尊重他人，尊重自己。',
#     'state': 0,
#     'duration': 685,
#     'rights': {'bp': 0,
#      'elec': 0,
#      'download': 0,
#      'movie': 0,
#      'pay': 0,
#      'hd5': 0,
#      'no_reprint': 1,
#      'autoplay': 1,
#      'ugc_pay': 0,
#      'is_cooperation': 0,
#      'ugc_pay_preview': 0,
#      'no_background': 0,
#      'arc_pay': 0,
#      'pay_free_watch': 0},
#     'owner': {'mid': 517327498,
#      'name': '罗翔说刑法',
#      'face': 'https://i1.hdslb.com/bfs/face/4e5d0a51273fe3f8fabc700b6a71bb8a38c9e21e.jpg'},
#     'stat': {'aid': 114511981843933,
#      'view': 631586,
#      'danmaku': 296,
#      'reply': 314,
#      'favorite': 3033,
#      'coin': 3189,
#      'share': 639,
#      'now_rank': 0,
#      'his_rank': 0,
#      'like': 33293,
#      'dislike': 0,
#      'vt': 0,
#      'vv': 631586,
#      'fav_g': 72,
#      'like_g': 0},
#     'dynamic': '',
#     'cid': 25798055563,
#     'dimension': {'width': 1920, 'height': 1080, 'rotate': 0},
#     'short_link_v2': 'https://b23.tv/BV1HBE1zfExS',
#     'first_frame': 'http://i2.hdslb.com/bfs/storyff/n250515ad250sybgxhlthk2b7cmfr25e_firsti.jpg',
#     'pub_location': '北京',
#     'cover43': 'http://i0.hdslb.com/bfs/archive/d6327c5534e0fdc4f829b8f45dc1e23b9fd4fbdd.jpg',
#     'tidv2': 2112,
#     'tnamev2': '护肤',
#     'pid_v2': 1014,
#     'pid_name_v2': '时尚美妆',
#     'bvid': 'BV1HBE1zfExS',
#     'season_type': 0,
#     'is_ogv': False,
#     'ogv_info': None,
#     'enable_vt': 0,
#     'ai_rcmd': None,
#     'rcmd_reason': '法外狂徒张三缘何成为化妆品受害人？'}]}}

# %%
pub_location = data_dict["pub_location"]

print(pub_location)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pub_location = data_dict["pub_location"]
#       3 print(pub_location)
#
# KeyError: 'pub_location'
