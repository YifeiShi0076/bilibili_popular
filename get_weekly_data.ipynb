# %%
import time

import pandas as pd
import requests
import os

# %%
import requests

# 目标 URL
url = "https://api.bilibili.com/x/web-interface/popular/series/one?number=1"

# 自定义请求头（可选）
custom_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# 发送请求
try:
    response = requests.get(url, headers=custom_headers)

    # 获取请求标头
    request_headers_dict = dict(response.request.headers)
    print("请求标头:")
    print(request_headers_dict)
except requests.exceptions.RequestException as e:
    print(f"请求失败: {e}")
# Out:
# 请求标头:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
def load_cookies(file_path):
    """
    从文件中加载 Cookie 并返回字符串
    """
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            cookies = file.read().strip()
            return cookies
    except FileNotFoundError:
        print(f"Cookie 文件未找到: {file_path}")
        return None
    except Exception as e:
        print(f"读取 Cookie 文件时出错: {e}")
        return None

# %%
# 定义cookie内容文件路径
cookie_file_path = os.path.join(os.getcwd(), "cookies.txt")
# 加载 Cookie
myCookie = load_cookies(cookie_file_path)
print(myCookie)
# Out:
# buvid3=EAA865F3-78A7-DDA1-AFB2-45B889942D4E63454infoc; b_nut=1741444563; _uuid=1F7F6C39-DF101-9396-B1077-1C4E527A101AC62871infoc; enable_web_push=DISABLE; enable_feed_channel=ENABLE; DedeUserID=497403294; DedeUserID__ckMd5=655ec9faf463886d; LIVE_BUVID=AUTO8817414446344917; PVID=2; header_theme_version=CLOSE; rpdid=|(JYYJJk~m~)0J'u~RuR)mu)~; buvid4=A3C08EE8-76C8-6C81-026D-83F2EE1FB05768985-024082614-2LSV8bAhVjTt1j%2F%2B2f5Wpg%3D%3D; CURRENT_QUALITY=112; fingerprint=8f77e620acf296c9024f5c5457a27b5d; buvid_fp_plain=undefined; buvid_fp=8f77e620acf296c9024f5c5457a27b5d; home_feed_column=5; browser_resolution=1552-719; hit-dyn-v2=1; bili_ticket=eyJhbGciOiJIUzI1NiIsImtpZCI6InMwMyIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NDgwOTEwNzgsImlhdCI6MTc0NzgzMTgxOCwicGx0IjotMX0.fXi0APaG8eYNVbF3UFFy2i7zGyM9p1oajX8fAsoccTI; bili_ticket_expires=1748091018; SESSDATA=8a325c38%2C1763473340%2C87e61%2A52CjDBUIE_VoQ2ZB3uERVrnE0N7W-35k-QKkVYcgmnU2U4tWP0P4n4cKaDtEU7T-Q9VYkSVjRIWWktM0swajQzdk5rWUd0d0VQU2NzSXlzTm5SU2Z6VHpOUExlQzh5NENQUEFNMGt4ajJDRkZYOGRIUzJHeUN2VURmdktKOW9HQS1HNHNrcVJ4VDRnIIEC; bili_jct=fe665230df1b6c6775d3eed297518d0d; bp_t_offset_497403294=1069807492222943232; CURRENT_FNVAL=4048; b_lsid=1086C102E1_19700D2B8F6

# %%
myHeader = {
        "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "accept-encoding":"gzip, deflate, br, zstd",
        "accept-language":"zh-CN,zh;q=0.9,en;q=0.8",
        "cache-control":"max-age=0",
        # 在根目录下新建一个cookies.txt文件，将你的浏览器cookie复制进来即可。注意在提交推送时将其设置为git忽略文件
        "cookie":myCookie,
        "priority":"u=0, i",
        "sec-ch-ua":'''"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"''',
        "sec-ch-ua-mobile":"?0",
        "sec-ch-ua-platform":'''"Windows"''',
        "sec-fetch-dest":"document",
        "sec-fetch-mode":"navigate",
        "sec-fetch-site":"none",
        "sec-fetch-user":"?1",
        "upgrade-insecure-requests":"1",
        "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36"
    }

# %%
df_lst = []
columns = ['date_name', 'date_label', 'aid', 'tid', 'tname', 'title', 'duration', 'mid', 'name', 'view', 'danmaku', 'reply', 'favorite', 'coin', 'share', 'like', 'short_link_v2', 'pub_location', 'pubdate', 'rcmd_reason']

# %%
# def fetch_TAG(
#         aid: int
# ):
#     url = f"https://api.bilibili.com/x/web-interface/view/detail/tag?aid={aid}"
#     headers = myHeader.copy()
#     response = requests.get(url, headers=headers)
#     data = response.json()
#     if data.get("code") ==0 in data and data.get("data") is not None:
#         data_list = data['data']

# %%
def fetch_data(
    page: int
):
    url = f"https://api.bilibili.com/x/web-interface/popular/series/one?number={page}"
    headers = myHeader.copy()
    response = requests.get(url, headers=headers)
    data = response.json()
    if data.get('code') == 0 and 'data' in data and 'list' in data.get('data', {}):
        data_list = data['data']['list']
        data_config = data['data']['config']
        # 获取时间信息
        date_name = data_config.get('name')
        date_label = data_config.get('label')

        for item in data_list:
            tmp = []
            tmp.append(date_name)                                  # 每周必看期数
            tmp.append(date_label)

            tmp.append(item.get('aid', None))                      # 视频ID
            tmp.append(item.get('tid', None))                      # 分区ID
            tmp.append(item.get('tname', None))                    # 分区
            tmp.append(item.get('title', None))                    # 标题
            tmp.append(item.get('duration', None))                 # 时长 s

            # 处理嵌套字典
            owner = item.get('owner', {})
            tmp.append(owner.get('mid', None))                    # up主id
            tmp.append(owner.get('name', None))                   # up主名称

            # 处理统计数据
            stat = item.get('stat', {})
            tmp.append(stat.get('view', None))                    # 播放量
            tmp.append(stat.get('danmaku', None))                 # 弹幕量
            tmp.append(stat.get('reply', None))                   # 评论量
            tmp.append(stat.get('favorite', None))                # 收藏量
            tmp.append(stat.get('coin', None))                    # 硬币量
            tmp.append(stat.get('share', None))                   # 分享量
            tmp.append(stat.get('like', None))                    # 点赞量

            tmp.append(item.get('short_link_v2', None))           # 短链接
            tmp.append(item.get('pub_location', None))            # 位置
            tmp.append(item.get('pubdate', None))                 # 发布时间
            tmp.append(item.get('rcmd_reason', None))             # 推荐理由

            df_lst.append(tmp)
    else:
        print(f"Error fetching data of page {page}: {data.get('message', 'Unknown error')}")

# %%
for i in range(1, 323):
    try:
        print(f"Try to fetch data of page {i} ……")
        fetch_data(i)
    except Exception as e:
        print(f"Error fetching data of page {i}: {e}")
        continue
# Out:
# Try to fetch data of page 1 ……
# Try to fetch data of page 2 ……
# Try to fetch data of page 3 ……
# Try to fetch data of page 4 ……
# Try to fetch data of page 5 ……
# Try to fetch data of page 6 ……
# Try to fetch data of page 7 ……
# Try to fetch data of page 8 ……
# Try to fetch data of page 9 ……
# Try to fetch data of page 10 ……
# Try to fetch data of page 11 ……
# Try to fetch data of page 12 ……
# Try to fetch data of page 13 ……
# Try to fetch data of page 14 ……
# Try to fetch data of page 15 ……
# Try to fetch data of page 16 ……
# Try to fetch data of page 17 ……
# Try to fetch data of page 18 ……
# Try to fetch data of page 19 ……
# Try to fetch data of page 20 ……
# Try to fetch data of page 21 ……
# Try to fetch data of page 22 ……
# Try to fetch data of page 23 ……
# Try to fetch data of page 24 ……
# Try to fetch data of page 25 ……
# Try to fetch data of page 26 ……
# Try to fetch data of page 27 ……
# Try to fetch data of page 28 ……
# Try to fetch data of page 29 ……
# Try to fetch data of page 30 ……
# Try to fetch data of page 31 ……
# Try to fetch data of page 32 ……
# Try to fetch data of page 33 ……
# Try to fetch data of page 34 ……
# Try to fetch data of page 35 ……
# Try to fetch data of page 36 ……
# Try to fetch data of page 37 ……
# Try to fetch data of page 38 ……
# Try to fetch data of page 39 ……
# Try to fetch data of page 40 ……
# Try to fetch data of page 41 ……
# Try to fetch data of page 42 ……
# Try to fetch data of page 43 ……
# Try to fetch data of page 44 ……
# Try to fetch data of page 45 ……
# Try to fetch data of page 46 ……
# Try to fetch data of page 47 ……
# Try to fetch data of page 48 ……
# Try to fetch data of page 49 ……
# Try to fetch data of page 50 ……
# Try to fetch data of page 51 ……
# Try to fetch data of page 52 ……
# Try to fetch data of page 53 ……
# Try to fetch data of page 54 ……
# Try to fetch data of page 55 ……
# Try to fetch data of page 56 ……
# Try to fetch data of page 57 ……
# Try to fetch data of page 58 ……
# Try to fetch data of page 59 ……
# Try to fetch data of page 60 ……
# Try to fetch data of page 61 ……
# Try to fetch data of page 62 ……
# Try to fetch data of page 63 ……
# Try to fetch data of page 64 ……
# Try to fetch data of page 65 ……
# Try to fetch data of page 66 ……
# Try to fetch data of page 67 ……
# Try to fetch data of page 68 ……
# Try to fetch data of page 69 ……
# Try to fetch data of page 70 ……
# Try to fetch data of page 71 ……
# Try to fetch data of page 72 ……
# Try to fetch data of page 73 ……
# Try to fetch data of page 74 ……
# Try to fetch data of page 75 ……
# Try to fetch data of page 76 ……
# Try to fetch data of page 77 ……
# Try to fetch data of page 78 ……
# Try to fetch data of page 79 ……
# Try to fetch data of page 80 ……
# Try to fetch data of page 81 ……
# Try to fetch data of page 82 ……
# Try to fetch data of page 83 ……
# Try to fetch data of page 84 ……
# Try to fetch data of page 85 ……
# Try to fetch data of page 86 ……
# Try to fetch data of page 87 ……
# Try to fetch data of page 88 ……
# Try to fetch data of page 89 ……
# Try to fetch data of page 90 ……
# Try to fetch data of page 91 ……
# Try to fetch data of page 92 ……
# Try to fetch data of page 93 ……
# Try to fetch data of page 94 ……
# Try to fetch data of page 95 ……
# Try to fetch data of page 96 ……
# Try to fetch data of page 97 ……
# Try to fetch data of page 98 ……
# Try to fetch data of page 99 ……
# Try to fetch data of page 100 ……
# Try to fetch data of page 101 ……
# Try to fetch data of page 102 ……
# Try to fetch data of page 103 ……
# Try to fetch data of page 104 ……
# Try to fetch data of page 105 ……
# Error fetching data of page 105: 啥都木有
# Try to fetch data of page 106 ……
# Try to fetch data of page 107 ……
# Try to fetch data of page 108 ……
# Try to fetch data of page 109 ……
# Try to fetch data of page 110 ……
# Try to fetch data of page 111 ……
# Try to fetch data of page 112 ……
# Try to fetch data of page 113 ……
# Try to fetch data of page 114 ……
# Try to fetch data of page 115 ……
# Try to fetch data of page 116 ……
# Try to fetch data of page 117 ……
# Try to fetch data of page 118 ……
# Try to fetch data of page 119 ……
# Try to fetch data of page 120 ……
# Try to fetch data of page 121 ……
# Try to fetch data of page 122 ……
# Try to fetch data of page 123 ……
# Try to fetch data of page 124 ……
# Try to fetch data of page 125 ……
# Try to fetch data of page 126 ……
# Try to fetch data of page 127 ……
# Try to fetch data of page 128 ……
# Try to fetch data of page 129 ……
# Try to fetch data of page 130 ……
# Try to fetch data of page 131 ……
# Try to fetch data of page 132 ……
# Try to fetch data of page 133 ……
# Try to fetch data of page 134 ……
# Try to fetch data of page 135 ……
# Try to fetch data of page 136 ……
# Try to fetch data of page 137 ……
# Try to fetch data of page 138 ……
# Try to fetch data of page 139 ……
# Try to fetch data of page 140 ……
# Try to fetch data of page 141 ……
# Try to fetch data of page 142 ……
# Try to fetch data of page 143 ……
# Try to fetch data of page 144 ……
# Try to fetch data of page 145 ……
# Try to fetch data of page 146 ……
# Try to fetch data of page 147 ……
# Try to fetch data of page 148 ……
# Try to fetch data of page 149 ……
# Try to fetch data of page 150 ……
# Try to fetch data of page 151 ……
# Try to fetch data of page 152 ……
# Try to fetch data of page 153 ……
# Try to fetch data of page 154 ……
# Try to fetch data of page 155 ……
# Try to fetch data of page 156 ……
# Try to fetch data of page 157 ……
# Try to fetch data of page 158 ……
# Try to fetch data of page 159 ……
# Try to fetch data of page 160 ……
# Try to fetch data of page 161 ……
# Try to fetch data of page 162 ……
# Try to fetch data of page 163 ……
# Try to fetch data of page 164 ……
# Try to fetch data of page 165 ……
# Try to fetch data of page 166 ……
# Try to fetch data of page 167 ……
# Try to fetch data of page 168 ……
# Try to fetch data of page 169 ……
# Try to fetch data of page 170 ……
# Try to fetch data of page 171 ……
# Try to fetch data of page 172 ……
# Try to fetch data of page 173 ……
# Try to fetch data of page 174 ……
# Try to fetch data of page 175 ……
# Try to fetch data of page 176 ……
# Try to fetch data of page 177 ……
# Try to fetch data of page 178 ……
# Try to fetch data of page 179 ……
# Try to fetch data of page 180 ……
# Try to fetch data of page 181 ……
# Try to fetch data of page 182 ……
# Try to fetch data of page 183 ……
# Try to fetch data of page 184 ……
# Try to fetch data of page 185 ……
# Try to fetch data of page 186 ……
# Try to fetch data of page 187 ……
# Try to fetch data of page 188 ……
# Try to fetch data of page 189 ……
# Try to fetch data of page 190 ……
# Try to fetch data of page 191 ……
# Try to fetch data of page 192 ……
# Try to fetch data of page 193 ……
# Try to fetch data of page 194 ……
# Try to fetch data of page 195 ……
# Try to fetch data of page 196 ……
# Try to fetch data of page 197 ……
# Try to fetch data of page 198 ……
# Try to fetch data of page 199 ……
# Try to fetch data of page 200 ……
# Try to fetch data of page 201 ……
# Try to fetch data of page 202 ……
# Try to fetch data of page 203 ……
# Try to fetch data of page 204 ……
# Try to fetch data of page 205 ……
# Try to fetch data of page 206 ……
# Try to fetch data of page 207 ……
# Try to fetch data of page 208 ……
# Try to fetch data of page 209 ……
# Try to fetch data of page 210 ……
# Try to fetch data of page 211 ……
# Try to fetch data of page 212 ……
# Try to fetch data of page 213 ……
# Try to fetch data of page 214 ……
# Try to fetch data of page 215 ……
# Try to fetch data of page 216 ……
# Try to fetch data of page 217 ……
# Try to fetch data of page 218 ……
# Try to fetch data of page 219 ……
# Try to fetch data of page 220 ……
# Try to fetch data of page 221 ……
# Try to fetch data of page 222 ……
# Try to fetch data of page 223 ……
# Try to fetch data of page 224 ……
# Try to fetch data of page 225 ……
# Try to fetch data of page 226 ……
# Try to fetch data of page 227 ……
# Try to fetch data of page 228 ……
# Try to fetch data of page 229 ……
# Try to fetch data of page 230 ……
# Try to fetch data of page 231 ……
# Try to fetch data of page 232 ……
# Try to fetch data of page 233 ……
# Try to fetch data of page 234 ……
# Try to fetch data of page 235 ……
# Try to fetch data of page 236 ……
# Try to fetch data of page 237 ……
# Try to fetch data of page 238 ……
# Try to fetch data of page 239 ……
# Try to fetch data of page 240 ……
# Try to fetch data of page 241 ……
# Try to fetch data of page 242 ……
# Try to fetch data of page 243 ……
# Try to fetch data of page 244 ……
# Try to fetch data of page 245 ……
# Try to fetch data of page 246 ……
# Try to fetch data of page 247 ……
# Try to fetch data of page 248 ……
# Try to fetch data of page 249 ……
# Try to fetch data of page 250 ……
# Try to fetch data of page 251 ……
# Try to fetch data of page 252 ……
# Try to fetch data of page 253 ……
# Try to fetch data of page 254 ……
# Try to fetch data of page 255 ……
# Try to fetch data of page 256 ……
# Try to fetch data of page 257 ……
# Try to fetch data of page 258 ……
# Try to fetch data of page 259 ……
# Try to fetch data of page 260 ……
# Try to fetch data of page 261 ……
# Try to fetch data of page 262 ……
# Try to fetch data of page 263 ……
# Try to fetch data of page 264 ……
# Try to fetch data of page 265 ……
# Try to fetch data of page 266 ……
# Try to fetch data of page 267 ……
# Try to fetch data of page 268 ……
# Try to fetch data of page 269 ……
# Try to fetch data of page 270 ……
# Try to fetch data of page 271 ……
# Try to fetch data of page 272 ……
# Try to fetch data of page 273 ……
# Try to fetch data of page 274 ……
# Try to fetch data of page 275 ……
# Try to fetch data of page 276 ……
# Try to fetch data of page 277 ……
# Try to fetch data of page 278 ……
# Try to fetch data of page 279 ……
# Try to fetch data of page 280 ……
# Try to fetch data of page 281 ……
# Try to fetch data of page 282 ……
# Try to fetch data of page 283 ……
# Try to fetch data of page 284 ……
# Try to fetch data of page 285 ……
# Try to fetch data of page 286 ……
# Try to fetch data of page 287 ……
# Try to fetch data of page 288 ……
# Try to fetch data of page 289 ……
# Try to fetch data of page 290 ……
# Try to fetch data of page 291 ……
# Try to fetch data of page 292 ……
# Try to fetch data of page 293 ……
# Try to fetch data of page 294 ……
# Try to fetch data of page 295 ……
# Try to fetch data of page 296 ……
# Try to fetch data of page 297 ……
# Try to fetch data of page 298 ……
# Try to fetch data of page 299 ……
# Try to fetch data of page 300 ……
# Try to fetch data of page 301 ……
# Try to fetch data of page 302 ……
# Try to fetch data of page 303 ……
# Try to fetch data of page 304 ……
# Try to fetch data of page 305 ……
# Try to fetch data of page 306 ……
# Try to fetch data of page 307 ……
# Try to fetch data of page 308 ……
# Try to fetch data of page 309 ……
# Try to fetch data of page 310 ……
# Try to fetch data of page 311 ……
# Try to fetch data of page 312 ……
# Try to fetch data of page 313 ……
# Try to fetch data of page 314 ……
# Try to fetch data of page 315 ……
# Try to fetch data of page 316 ……
# Try to fetch data of page 317 ……
# Try to fetch data of page 318 ……
# Try to fetch data of page 319 ……
# Try to fetch data of page 320 ……
# Try to fetch data of page 321 ……
# Try to fetch data of page 322 ……

# %%
df = pd.DataFrame(df_lst, columns=columns)
df.index = df.index + 1
df.to_csv('bilibili.csv', index=True, encoding='utf-8-sig')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11604 entries, 1 to 11604
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date_name      11604 non-null  object
#  1   date_label     11604 non-null  object
#  2   aid            11604 non-null  int64
#  3   tid            11604 non-null  int64
#  4   tname          11604 non-null  object
#  5   title          11604 non-null  object
#  6   duration       11604 non-null  int64
#  7   mid            11604 non-null  int64
#  8   name           11604 non-null  object
#  9   view           11604 non-null  int64
#  10  danmaku        11604 non-null  int64
#  11  reply          11604 non-null  int64
#  12  favorite       11604 non-null  int64
#  13  coin           11604 non-null  int64
#  14  share          11604 non-null  int64
#  15  like           11604 non-null  int64
#  16  short_link_v2  11604 non-null  object
#  17  pub_location   7590 non-null   object
#  18  pubdate        11604 non-null  int64
#  19  rcmd_reason    11604 non-null  object
# dtypes: int64(12), object(8)
# memory usage: 1.8+ MB

# %%
df
# Out:
#                      date_name     date_label              aid  tid tname  \
# 1        2019第1期 03.22 - 03.28    第1期(0329更新)         46900196  250    出行
# 2        2019第1期 03.22 - 03.28    第1期(0329更新)         47211520  251    三农
# 3        2019第1期 03.22 - 03.28    第1期(0329更新)         46567722  183  影视剪辑
# 4        2019第1期 03.22 - 03.28    第1期(0329更新)         47151947  253  动漫杂谈
# 5        2019第1期 03.22 - 03.28    第1期(0329更新)         46797630  212  美食侦探
# ...                        ...            ...              ...  ...   ...
# 11600  2025第322期 05.16 - 05.22  第322期(0523更新)  114527031136823   21    日常
# 11601  2025第322期 05.16 - 05.22  第322期(0523更新)  114529748914250  172  手机游戏
# 11602  2025第322期 05.16 - 05.22  第322期(0523更新)  114527064624802  213  美食测评
# 11603  2025第322期 05.16 - 05.22  第322期(0523更新)  114538892500953  220  动物二创
# 11604  2025第322期 05.16 - 05.22  第322期(0523更新)  114516679461115  212  美食侦探
#
#                                                    title  duration  \
# 1                                   这集vlog我们拍了十年，致最美好的青春       504
# 2                          华农兄弟：兄弟家的鱼跑河里去了，帮他网回来，一网下去还不少       312
# 3                                             【性转版】回家的诱惑       643
# 4                            哆啦A梦结局背后的秘密？从未播出的黑历史？真相出人意料       415
# 5                                   在中国挑战通宵卖烧烤！为啥美国没有这个？       326
# ...                                                  ...       ...
# 11600                                第一视角带你沉浸式体验修家电师傅的一天       173
# 11601                       【DNF手游】火力轰炸，弹无虚发！机械师、弹药专家上线！       105
# 11602                                挑战晨宇炒饭给华晨宇吃，没想到竟然……       610
# 11603                  《 鳞 甲 下 的 哀 伤 》我曾以鳞甲对抗世间万难，却败在了人心       272
# 11604  西安机械工程师街头卖鱿鱼，靠鱿鱼培养出俩孩子，一个硕士，一个博士。父爱伟大感人至深。#人间烟...       190
#
#                     mid         name     view  danmaku  reply  favorite  \
# 1             326257138  AresserA木恩木  5291250    68823  22401    239069
# 2             250858633         华农兄弟  2597156    21706   5662      4606
# 3               9813844    兰彻lancche  4871911    43825  12855    148897
# 4                730732       瓶子君152  2632263     5081   3431     52642
# 5             176037767        我是郭杰瑞  2640513    14319   3513      5156
# ...                 ...          ...      ...      ...    ...       ...
# 11600  3493284078946573         超越家电  2029113     4758   1578     11859
# 11601         325314188     地下城与勇士手游  1645399     1031    591      4593
# 11602         337521240     记录生活的蛋黄派  2271875     6727   2819     24140
# 11603         149574778        即刻自然说  5917903     2241   4451    134554
# 11604         660013124         曾哥振弟  2720529     4416   3864     36779
#
#          coin   share    like                short_link_v2 pub_location  \
# 1      552760  212104  506117  https://b23.tv/BV14b411J7ML         None
# 2       28555    2646   76837  https://b23.tv/BV15b41147uu         None
# 3      216302  160208  251293  https://b23.tv/BV1xb411n7L6           湖南
# 4      134616    4288  161324  https://b23.tv/BV1Qb41177Vm           美国
# 5       18916    2074   77384  https://b23.tv/BV1Rb411E7yi         None
# ...       ...     ...     ...                          ...          ...
# 11600    4910    3699  158056  https://b23.tv/BV1ZhJuzQEPn           山东
# 11601    1360     442   17824  https://b23.tv/BV1PJEUzzE76           广东
# 11602   43342    7584  109090  https://b23.tv/BV1t2JuzrE57           广东
# 11603   65829    2449  243262  https://b23.tv/BV1WDJtzDELM           广西
# 11604   26118   11050  306276  https://b23.tv/BV1oUEszhEgF           安徽
#
#           pubdate                rcmd_reason
# 1      1553152210  暴风流泪推荐！今天也是为别人的神仙爱情流泪的一天！
# 2      1553427011  村霸兄弟又上线了！这次他们把魔抓伸向了兄弟家的鱼！
# 3      1552823023      无论是创意、配音还是剪辑，全都是超高质量！
# 4      1553396443
# 5      1553050747
# ...           ...                        ...
# 11600  1747560600               假面骑士腰带能修吗？能！
# 11601  1747627200                 耍帅就像呼吸一样简单
# 11602  1747560600          这一切都要从紧张是你的武器开始说起
# 11603  1747725080                  穿山甲到底说了什么
# 11604  1747386140                    大爷永远是大爷
#
# [11604 rows x 20 columns]

# %% [markdown]
# ### 数据处理与可视化
